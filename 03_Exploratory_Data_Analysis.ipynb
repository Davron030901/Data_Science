# %% [markdown]
# <a href="https://colab.research.google.com/github/Davron030901/Data_Science/blob/main/03_Exploratory_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# # Exploratory Data Analysis
#
# In this section, we will seek to gain insight into the data using visuals such as: Bar charts, Heat maps, histograms, scatter plots, and more.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The exercises for this challenge lab are found in the EDA section.
# # EXERCISES  - Under the Exploratory Data Analysis Section
# 1. Bar Chart - Count how contracts are distributed
# 2. Pie Chart - Graph contract type by distribution
# 3. Scatter Chart - Graph Tenure in Months vs. Total Revenue
# 4. Heat Map - Enter Code to visualize feature relationships
# 5. Histogram - Graph a histogram of Tenure
# 6. Simple Feature Engineering - Create the Customer Lifetime Value
# 7. Save the cleaned file - code provided.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Load and Explore the Data

# %% [markdown]
# In the previous lab, you performed data preprocessing. In this exercise, you perform Exploratory Data Analysis (EDA).
#
# First, upload the cleaned_telecom.csv file.
#
# Next, run all the cells in the **Load and Explore the Data** and in the Data Preprocessing sections. Your hands-on exercise begins in the Data Visualization and Analysis section.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Step 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#%matplotlib inline
import seaborn as sns

# %% [markdown]
# ##Step 2. Load Data

# %%
#Load the dataset
# !wget https://raw.githubusercontent.com/Davron030901/Data_Science/main/data/telecom_dataset.csv
df=pd.read_csv('/content/telecom_dataset.csv')
# Out:
# --2025-02-03 06:48:18--  https://raw.githubusercontent.com/Davron030901/Data_Science/main/data/telecom_dataset.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1211075 (1.2M) [text/plain]
# Saving to: ‘telecom_dataset.csv’
#
# telecom_dataset.csv 100%[===================>]   1.15M  --.-KB/s    in 0.06s
#
# 2025-02-03 06:48:18 (19.4 MB/s) - ‘telecom_dataset.csv’ saved [1211075/1211075]

# %% [markdown]
# ##Step 3. Initial Exploration

# %% [markdown]
# #### 3.1 Show first five rows of the DataFrame.

# %%
# Show first five rows

df.head()
# Out:
#   Customer_ID  Tenure          City  Zip Code   Latitude   Longitude    Offer  \
# 0  0002-ORFBO       9  Frazier Park     93225  34.827662 -118.999073      NaN
# 1  0003-MKNFE       9      Glendale     91206  34.162515 -118.203869      NaN
# 2  0004-TLHLJ       4    Costa Mesa     92627  33.645672 -117.922613  Offer E
# 3  0011-IGKFF      13      Martinez     94553  38.014457 -122.115432  Offer D
# 4  0013-EXCHZ       3     Camarillo     93010  34.227846 -119.079903      NaN
#
#   Phone Service Multiple Lines Internet Service  ... Monthly Charge  \
# 0           Yes             No              Yes  ...           65.6
# 1           Yes            Yes              Yes  ...           -4.0
# 2           Yes             No              Yes  ...           73.9
# 3           Yes             No              Yes  ...           98.0
# 4           Yes             No              Yes  ...           83.9
#
#    Total Charges Total Revenue  Gender Age Married Kidhome Teenhome   Income  \
# 0         593.30        974.81  Female  37     Yes       0        0  30507.0
# 1         542.40        610.28    Male  46      No       0        1  59892.0
# 2         280.85        415.45    Male  50      No       0        1  70545.0
# 3        1237.85       1599.51    Male  78     Yes       0        0  57100.0
# 4         267.40        289.54  Female  75     Yes       1        1  49096.0
#
#   Churn
# 0    No
# 1    No
# 2   Yes
# 3    No
# 4   Yes
#
# [5 rows x 31 columns]

# %% [markdown]
# ### 3.2 Show the last five rows of the DataFrame

# %%
df.tail()
# Out:
#      Customer_ID  Tenure          City  Zip Code   Latitude   Longitude  \
# 7038  9987-LUTYD      13       La Mesa     91941  32.759327 -116.997260
# 7039  9992-RRAMN      22     Riverbank     95367  37.734971 -120.954271
# 7040  9992-UJOEL       2           Elk     95432  39.108252 -123.645121
# 7041  9993-LHIEB      67  Solana Beach     92075  33.001813 -117.263628
# 7042  9995-HOTOH      63   Sierra City     96125  39.600599 -120.636358
#
#         Offer Phone Service Multiple Lines Internet Service  ...  \
# 7038  Offer D           Yes             No              Yes  ...
# 7039  Offer D           Yes            Yes              Yes  ...
# 7040  Offer E           Yes             No              Yes  ...
# 7041  Offer A           Yes             No              Yes  ...
# 7042      NaN            No            NaN              Yes  ...
#
#      Monthly Charge  Total Charges Total Revenue  Gender Age Married Kidhome  \
# 7038          55.15         742.90       1349.74  Female  20      No       1
# 7039          85.10        1873.70       2230.10    Male  40     Yes       0
# 7040          50.30          92.75        129.99    Male  22      No       1
# 7041          67.85        4627.65       4769.69    Male  21     Yes       0
# 7042          59.00        3707.60       3707.60    Male  36     Yes       0
#
#      Teenhome   Income Churn
# 7038        1  26290.0    No
# 7039        1  63381.0    No
# 7040        0  35544.0    No
# 7041        0  63033.0   Yes
# 7042        0  10979.0    No
#
# [5 rows x 31 columns]

# %% [markdown]
# ### 3.3 Show information about the Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer_ID             7043 non-null   object
#  1   Tenure                  7043 non-null   int64
#  2   City                    7043 non-null   object
#  3   Zip Code                7043 non-null   int64
#  4   Latitude                7043 non-null   float64
#  5   Longitude               7043 non-null   float64
#  6   Offer                   3166 non-null   object
#  7   Phone Service           7043 non-null   object
#  8   Multiple Lines          6361 non-null   object
#  9   Internet Service        7043 non-null   object
#  10  Internet Type           5517 non-null   object
#  11  Gigabits Used           5517 non-null   float64
#  12  Online Security         5517 non-null   object
#  13  Online Backup           5517 non-null   object
#  14  Device Protection Plan  5517 non-null   object
#  15  Premium Tech Support    5517 non-null   object
#  16  Streaming TV            5517 non-null   object
#  17  Streaming Movies        5517 non-null   object
#  18  Unlimited Data          5517 non-null   object
#  19  Contract                7043 non-null   object
#  20  Payment Method          7042 non-null   object
#  21  Monthly Charge          7043 non-null   float64
#  22  Total Charges           7043 non-null   float64
#  23  Total Revenue           7043 non-null   float64
#  24  Gender                  7043 non-null   object
#  25  Age                     7043 non-null   int64
#  26  Married                 7043 non-null   object
#  27  Kidhome                 7043 non-null   int64
#  28  Teenhome                7043 non-null   int64
#  29  Income                  6962 non-null   float64
#  30  Churn                   7043 non-null   object
# dtypes: float64(7), int64(5), object(19)
# memory usage: 1.7+ MB

# %% [markdown]
# #### 3.3.1 NEW: Let's add code to convert the column names to lowercase

# %%
# Convert column names to lowercase
df.columns = df.columns.str.lower()

#Replace Spaces with Underscores
df.columns = df.columns.str.replace(' ', '_')

# %% [markdown]
# #### 3.3.2 NEW: Let's add code to replace spaces with underscores.

# %%
# Replaces spaces with underscores.

df.rename(columns=lambda x: x.replace(' ', '_'), inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             7043 non-null   object
#  1   tenure                  7043 non-null   int64
#  2   city                    7043 non-null   object
#  3   zip_code                7043 non-null   int64
#  4   latitude                7043 non-null   float64
#  5   longitude               7043 non-null   float64
#  6   offer                   3166 non-null   object
#  7   phone_service           7043 non-null   object
#  8   multiple_lines          6361 non-null   object
#  9   internet_service        7043 non-null   object
#  10  internet_type           5517 non-null   object
#  11  gigabits_used           5517 non-null   float64
#  12  online_security         5517 non-null   object
#  13  online_backup           5517 non-null   object
#  14  device_protection_plan  5517 non-null   object
#  15  premium_tech_support    5517 non-null   object
#  16  streaming_tv            5517 non-null   object
#  17  streaming_movies        5517 non-null   object
#  18  unlimited_data          5517 non-null   object
#  19  contract                7043 non-null   object
#  20  payment_method          7042 non-null   object
#  21  monthly_charge          7043 non-null   float64
#  22  total_charges           7043 non-null   float64
#  23  total_revenue           7043 non-null   float64
#  24  gender                  7043 non-null   object
#  25  age                     7043 non-null   int64
#  26  married                 7043 non-null   object
#  27  kidhome                 7043 non-null   int64
#  28  teenhome                7043 non-null   int64
#  29  income                  6962 non-null   float64
#  30  churn                   7043 non-null   object
# dtypes: float64(7), int64(5), object(19)
# memory usage: 1.7+ MB

# %% [markdown]
# ### 3.4 Show the DataFrame shape
#
# The .shape() method gives you the number of rows and columns in the dataset. You can also see this information in the df.info() output.

# %%
df.shape
# Out:
# (7043, 31)

# %% [markdown]
# ### 3.5 Show the data types
#
# Show DataFrame data types. Although the df.info() provides this information, it is good to see the column datatypes on their own.

# %%
df.dtypes
# Out:
# customer_id                object
# tenure                      int64
# city                       object
# zip_code                    int64
# latitude                  float64
# longitude                 float64
# offer                      object
# phone_service              object
# multiple_lines             object
# internet_service           object
# internet_type              object
# gigabits_used             float64
# online_security            object
# online_backup              object
# device_protection_plan     object
# premium_tech_support       object
# streaming_tv               object
# streaming_movies           object
# unlimited_data             object
# contract                   object
# payment_method             object
# monthly_charge            float64
# total_charges             float64
# total_revenue             float64
# gender                     object
# age                         int64
# married                    object
# kidhome                     int64
# teenhome                    int64
# income                    float64
# churn                      object
# dtype: object

# %% [markdown]
# ### 3.6 Show DataFrame statistics
#
# The describe() method computes and displays summary statistics for the dataset.

# %%
df.describe()
# Out:
#             tenure      zip_code     latitude    longitude  gigabits_used  \
# count  7043.000000   7043.000000  7043.000000  7043.000000    5517.000000
# mean     32.386767  93486.070567    36.197455  -119.756684      26.189958
# std      24.542061   1856.767505     2.468929     2.154425      19.586585
# min       1.000000  90001.000000    32.555828  -124.301372       2.000000
# 25%       9.000000  92101.000000    33.990646  -121.788090      13.000000
# 50%      29.000000  93518.000000    36.205465  -119.595293      21.000000
# 75%      55.000000  95329.000000    38.161321  -117.969795      30.000000
# max      72.000000  96150.000000    41.962127  -114.192901      85.000000
#
#        monthly_charge  total_charges  total_revenue          age      kidhome  \
# count     7043.000000    7043.000000    7043.000000  7043.000000  7043.000000
# mean        63.596131    2280.381264    3034.379056    46.509726     0.446969
# std         31.204743    2266.220462    2865.204542    16.750352     0.542819
# min        -10.000000      18.800000      21.360000    19.000000     0.000000
# 25%         30.400000     400.150000     605.610000    32.000000     0.000000
# 50%         70.050000    1394.550000    2108.640000    46.000000     0.000000
# 75%         89.750000    3786.600000    4801.145000    60.000000     1.000000
# max        118.750000    8684.800000   11979.340000    80.000000     2.000000
#
#           teenhome         income
# count  7043.000000    6962.000000
# mean      0.503905   52107.377190
# std       0.544608   23930.386972
# min       0.000000    1730.000000
# 25%       0.000000   35395.000000
# 50%       0.000000   51369.000000
# 75%       1.000000   69016.000000
# max       2.000000  666666.000000

# %% [markdown]
# Below is bar charts that plots the distribution of each numerical column.

# %%
# Extracting numerical columns
numeric_columns = df.columns[ df.dtypes!='object']

# Plotting the distribution of each numerical column
for col in numeric_columns:
  plt.hist(df[col])
  plt.xlabel(col)
  plt.ylabel('Frequency')
  plt.title(f'Distribution of {col}')
  plt.show()

# %% [markdown]
# ### 3.7 Check for duplicate values
#
# Checking for duplicates helps identify rows that are exact copies of others. These duplicates can arise from data entry errors, merging datasets, or repeated measurements.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 3.8 Check for Missing (Null) Values
#
# You probably saw null values in the a column when your reviewed the df.info() output. Here is the .isnull() method, which shows you any null values in the dataset as well.

# %%
df.isnull().sum()
# Out:
# customer_id                  0
# tenure                       0
# city                         0
# zip_code                     0
# latitude                     0
# longitude                    0
# offer                     3877
# phone_service                0
# multiple_lines             682
# internet_service             0
# internet_type             1526
# gigabits_used             1526
# online_security           1526
# online_backup             1526
# device_protection_plan    1526
# premium_tech_support      1526
# streaming_tv              1526
# streaming_movies          1526
# unlimited_data            1526
# contract                     0
# payment_method               1
# monthly_charge               0
# total_charges                0
# total_revenue                0
# gender                       0
# age                          0
# married                      0
# kidhome                      0
# teenhome                     0
# income                      81
# churn                        0
# dtype: int64

# %% [markdown]
# #### 3.8.1 Visualize the missing values

# %%
# Add the msno library to visualize the missing values

import missingno as msno

msno.bar(df)
# Out:
# <Axes: >

# %% [markdown]
# ### 3.9 Check for Unique Values

# %% [markdown]
# Show unique values in a few columns with the highest missing values - just for curiosity.
#
#
# ---

# %%
# Get unique values for a specific column
print("Unique values in 'offer':", df['offer'].unique())
# Out:
# Unique values in 'offer': [nan 'Offer E' 'Offer D' 'Offer A' 'Offer B' 'Offer C']

# %% [markdown]
# What does this all mean?
#
# * nan: Represents missing values in the 'Offer' column. It indicates that there are entries in this column where the data is missing.
# * 'Offer E', 'Offer D', 'Offer A', 'Offer B', 'Offer C': These are the unique non-missing values present in the 'Offer' column. Each represents a different offer.
#
# Next Steps? We'll need to handle these data quality issues in the data preprocessing section!

# %%
# Get the count of unique values for each column
unique_counts = df.nunique()

print("Count of Unique Values for Each Column:\n", unique_counts)
# Out:
# Count of Unique Values for Each Column:
#  customer_id               7043
# tenure                      72
# city                      1106
# zip_code                  1626
# latitude                  1626
# longitude                 1625
# offer                        5
# phone_service                2
# multiple_lines               2
# internet_service             2
# internet_type                3
# gigabits_used               49
# online_security              2
# online_backup                2
# device_protection_plan       2
# premium_tech_support         2
# streaming_tv                 2
# streaming_movies             2
# unlimited_data               2
# contract                     3
# payment_method               3
# monthly_charge            1591
# total_charges             6540
# total_revenue             6975
# gender                       2
# age                         62
# married                      2
# kidhome                      3
# teenhome                     3
# income                    1974
# churn                        2
# dtype: int64

# %% [markdown]
# ### 3.10 Initial Check for Outliers
#
# On a column

# %%
# Create a box plot
plt.boxplot(df['age'])
plt.title('Box Plot of Age')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Step 1.  Handle Missing Values

# %% [markdown]
# Data Understanding:
#
# Note:  We have made this dataset intentionally "messy" when it comes to missing values. Before filling missing values, understand why data might be missing and whether imputation could bias your analyses.

# %% [markdown]
# **Methods**
#
# Use methods such as mean/median imputation, forward/backward fill, or dropping missing values depending on the context.

# %%
# Let's see information on the DataFrame again.
# Total row count is 7,043.
# Note both objects, integers, and floats have missing values.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             7043 non-null   object
#  1   tenure                  7043 non-null   int64
#  2   city                    7043 non-null   object
#  3   zip_code                7043 non-null   int64
#  4   latitude                7043 non-null   float64
#  5   longitude               7043 non-null   float64
#  6   offer                   3166 non-null   object
#  7   phone_service           7043 non-null   object
#  8   multiple_lines          6361 non-null   object
#  9   internet_service        7043 non-null   object
#  10  internet_type           5517 non-null   object
#  11  gigabits_used           5517 non-null   float64
#  12  online_security         5517 non-null   object
#  13  online_backup           5517 non-null   object
#  14  device_protection_plan  5517 non-null   object
#  15  premium_tech_support    5517 non-null   object
#  16  streaming_tv            5517 non-null   object
#  17  streaming_movies        5517 non-null   object
#  18  unlimited_data          5517 non-null   object
#  19  contract                7043 non-null   object
#  20  payment_method          7042 non-null   object
#  21  monthly_charge          7043 non-null   float64
#  22  total_charges           7043 non-null   float64
#  23  total_revenue           7043 non-null   float64
#  24  gender                  7043 non-null   object
#  25  age                     7043 non-null   int64
#  26  married                 7043 non-null   object
#  27  kidhome                 7043 non-null   int64
#  28  teenhome                7043 non-null   int64
#  29  income                  6962 non-null   float64
#  30  churn                   7043 non-null   object
# dtypes: float64(7), int64(5), object(19)
# memory usage: 1.7+ MB

# %% [markdown]
# Let's show the number of missing values for numbers and objects.

# %%
# Calculate missing values for numeric and object columns
missing_values_numeric = df.select_dtypes(include=['number']).isnull().sum()
missing_values_object = df.select_dtypes(include=['object']).isnull().sum()

# Display the results
print("Missing values in numeric columns:")
print(missing_values_numeric)
print("\nMissing values in object columns:")
print(missing_values_object)
# Out:
# Missing values in numeric columns:
# tenure               0
# zip_code             0
# latitude             0
# longitude            0
# gigabits_used     1526
# monthly_charge       0
# total_charges        0
# total_revenue        0
# age                  0
# kidhome              0
# teenhome             0
# income              81
# dtype: int64
#
# Missing values in object columns:
# customer_id                  0
# city                         0
# offer                     3877
# phone_service                0
# multiple_lines             682
# internet_service             0
# internet_type             1526
# online_security           1526
# online_backup             1526
# device_protection_plan    1526
# premium_tech_support      1526
# streaming_tv              1526
# streaming_movies          1526
# unlimited_data            1526
# contract                     0
# payment_method               1
# gender                       0
# married                      0
# churn                        0
# dtype: int64

# %%
# Put the columns that need to be filled in.

categorical_columns = ['multiple_lines',
       'internet_service', 'internet_type', 'online_security', 'online_backup',
       'device_protection_plan', 'premium_tech_support', 'streaming_tv',
       'streaming_movies', 'unlimited_data']

for column in categorical_columns:
    df[column].fillna(df[column].mode()[0], inplace=True)  # mode()[0] to get the most common value
# Out:
# <ipython-input-20-9363605478ea>:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(df[column].mode()[0], inplace=True)  # mode()[0] to get the most common value

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             7043 non-null   object
#  1   tenure                  7043 non-null   int64
#  2   city                    7043 non-null   object
#  3   zip_code                7043 non-null   int64
#  4   latitude                7043 non-null   float64
#  5   longitude               7043 non-null   float64
#  6   offer                   3166 non-null   object
#  7   phone_service           7043 non-null   object
#  8   multiple_lines          7043 non-null   object
#  9   internet_service        7043 non-null   object
#  10  internet_type           7043 non-null   object
#  11  gigabits_used           5517 non-null   float64
#  12  online_security         7043 non-null   object
#  13  online_backup           7043 non-null   object
#  14  device_protection_plan  7043 non-null   object
#  15  premium_tech_support    7043 non-null   object
#  16  streaming_tv            7043 non-null   object
#  17  streaming_movies        7043 non-null   object
#  18  unlimited_data          7043 non-null   object
#  19  contract                7043 non-null   object
#  20  payment_method          7042 non-null   object
#  21  monthly_charge          7043 non-null   float64
#  22  total_charges           7043 non-null   float64
#  23  total_revenue           7043 non-null   float64
#  24  gender                  7043 non-null   object
#  25  age                     7043 non-null   int64
#  26  married                 7043 non-null   object
#  27  kidhome                 7043 non-null   int64
#  28  teenhome                7043 non-null   int64
#  29  income                  6962 non-null   float64
#  30  churn                   7043 non-null   object
# dtypes: float64(7), int64(5), object(19)
# memory usage: 1.7+ MB

# %% [markdown]
# Looks like we missed two objects with missing values: "offer" and "payment_method". We also still have to numeric features with missing values: "gigabits_used" and "income".
#
# EXERCISE: offer and payment_method.

# %%
# This takes care of the object columns.

# Define the values to fill for each column
fill_values = {'offer': 'None', 'payment_method': 'Credit Card'}

# Fill missing values
df.fillna(fill_values, inplace=True)

# %%
# This takes care of the numeric columns.

# Calculate the mean for each column
mean_gigabits = df['gigabits_used'].mean()
mean_income = df['income'].mean()

# Fill missing values with the calculated means
df['gigabits_used'].fillna(mean_gigabits, inplace=True)
df['income'].fillna(mean_income, inplace=True)
# Out:
# <ipython-input-23-9cd5e76d80be>:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['gigabits_used'].fillna(mean_gigabits, inplace=True)
# <ipython-input-23-9cd5e76d80be>:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['income'].fillna(mean_income, inplace=True)

# %%
# Run this cell to confirm that all missing values are filled.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             7043 non-null   object
#  1   tenure                  7043 non-null   int64
#  2   city                    7043 non-null   object
#  3   zip_code                7043 non-null   int64
#  4   latitude                7043 non-null   float64
#  5   longitude               7043 non-null   float64
#  6   offer                   7043 non-null   object
#  7   phone_service           7043 non-null   object
#  8   multiple_lines          7043 non-null   object
#  9   internet_service        7043 non-null   object
#  10  internet_type           7043 non-null   object
#  11  gigabits_used           7043 non-null   float64
#  12  online_security         7043 non-null   object
#  13  online_backup           7043 non-null   object
#  14  device_protection_plan  7043 non-null   object
#  15  premium_tech_support    7043 non-null   object
#  16  streaming_tv            7043 non-null   object
#  17  streaming_movies        7043 non-null   object
#  18  unlimited_data          7043 non-null   object
#  19  contract                7043 non-null   object
#  20  payment_method          7043 non-null   object
#  21  monthly_charge          7043 non-null   float64
#  22  total_charges           7043 non-null   float64
#  23  total_revenue           7043 non-null   float64
#  24  gender                  7043 non-null   object
#  25  age                     7043 non-null   int64
#  26  married                 7043 non-null   object
#  27  kidhome                 7043 non-null   int64
#  28  teenhome                7043 non-null   int64
#  29  income                  7043 non-null   float64
#  30  churn                   7043 non-null   object
# dtypes: float64(7), int64(5), object(19)
# memory usage: 1.7+ MB

# %% [markdown]
# ## Step 2. No duplicate values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Step 3. Handle Data Type Inconsistency

# %% [markdown]
# Convert columns to appropriate data types using methods like astype() in Pandas.
#
#
# Zip Code has the incorrect data type. It is shown as an integer - it is not a number. In data processing and analytics, zip codes are often not treated as integers or numeric values, even though they consist of digits. See the course lesson on why this is the case.

# %%
# Enter the code to convert the 'zip_code" column to an object (string)

df['zip_code'] = df['zip_code'].astype(str)

# Enter the code to check the data type of the zip code column

print(df['zip_code'].dtype)
# Out:
# object

# %% [markdown]
# ## Step 4. Handle Outliers

# %% [markdown]
# An outlier is a data point in a data set that is distant from all other observations. A data point that lies outside the overall distribution of the dataset. Z score is an important concept in statistics. Z score is also called standard score. This score helps to understand if a data value is greater or smaller than mean and how far away it is from the mean. More specifically, Z score tells how many standard deviations away a data point is from the mean.

# %% [markdown]
# The results below are from our initial data check.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Let's create a z-score for the total revenue column, since it is one of the features that we'll need to calculate Customer Lifetime Value.

# %%
# Create a z-score for the column 'total_revenue'

from scipy import stats # SciPy is a widely-used library for scientific and technical computing in Python. The stats module within SciPy contains a wide range of statistical functions, probability distribu

z_scores = stats.zscore(df['total_revenue'])

# Display the z-scores
z_scores
# Out:
# 0      -0.718872
# 1      -0.846108
# 2      -0.914111
# 3      -0.500827
# 4      -0.958059
#           ...
# 7038   -0.588006
# 7039   -0.280726
# 7040   -1.013748
# 7041    0.605693
# 7042    0.234981
# Name: total_revenue, Length: 7043, dtype: float64

# %% [markdown]
# Check the rows with a z-score over 3. If there are rows with a z-score we can drop them. (Ektamaini, 2020) https://www.geeksforgeeks.org/z-score-for-outlier-detection-python/

# %%
# Check rows with a z-score over 3. A z-score A Z-score, also known as a standard score, measures how many standard deviations a data point is from the mean of the dataset. It is a way to standardize data points within a distribution, allowing for comparison across different scales or distributions.

df[(z_scores > 3)]
# Out:
#      customer_id  tenure           city zip_code   latitude   longitude  \
# 95    0164-APGRB      72      Calistoga    94515  38.629618 -122.593216
# 2686  3810-DVDQQ      72    Shasta Lake    96019  40.692523 -122.369876
# 3879  5451-YHYPW      72  San Francisco    94129  37.797526 -122.464531
# 5360  7569-NMZYQ      72     Middletown    95461  38.787446 -122.586750
# 5879  8263-QMNTJ      72  San Francisco    94104  37.791222 -122.402241
#
#         offer phone_service multiple_lines internet_service  ...  \
# 95    Offer A           Yes            Yes              Yes  ...
# 2686     None           Yes            Yes              Yes  ...
# 3879  Offer A           Yes            Yes              Yes  ...
# 5360     None           Yes            Yes              Yes  ...
# 5879  Offer A           Yes            Yes              Yes  ...
#
#      monthly_charge  total_charges total_revenue  gender age married kidhome  \
# 95           114.90        8496.70      11979.34  Female  56      No       0
# 2686         117.60        8308.90      11688.90  Female  28     Yes       0
# 3879         115.75        8443.70      11795.78  Female  75     Yes       0
# 5360         118.75        8672.45      11634.53  Female  33     Yes       1
# 5879         115.55        8425.30      11868.34    Male  46     Yes       0
#
#      teenhome   income churn
# 95          0  91249.0   Yes
# 2686        1  56129.0   Yes
# 3879        0  93790.0   Yes
# 5360        1  34026.0   Yes
# 5879        1  67680.0    No
#
# [5 rows x 31 columns]

# %% [markdown]
# There are five rows with a z-score over 3.

# %%
# Remove any rows with a z-score over 3 (keep rows with a z-score <3

df = df[(z_scores < 3)]

# %% [markdown]
# Let's check again - for rows with a z-score over 3.

# %%
# Check rows with a z-score over 3. A z-score A Z-score, also known as a standard score, measures how many standard deviations a data point is from the mean of the dataset. It is a way to standardize data points within a distribution, allowing for comparison across different scales or distributions.

df[(z_scores > 3)]
# Out:
# <ipython-input-30-2b2c33628063>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[(z_scores > 3)]
# Empty DataFrame
# Columns: [customer_id, tenure, city, zip_code, latitude, longitude, offer, phone_service, multiple_lines, internet_service, internet_type, gigabits_used, online_security, online_backup, device_protection_plan, premium_tech_support, streaming_tv, streaming_movies, unlimited_data, contract, payment_method, monthly_charge, total_charges, total_revenue, gender, age, married, kidhome, teenhome, income, churn]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# No rows with a z-score over three.

# %%
# Create a z-score for the column 'tenure'

from scipy import stats

z_scores = stats.zscore(df['tenure'])

# Display the z-scores
z_scores
# Out:
# 0      -0.952391
# 1      -0.952391
# 2      -1.156254
# 3      -0.789301
# 4      -1.197026
#           ...
# 7038   -0.789301
# 7039   -0.422348
# 7040   -1.237799
# 7041    1.412417
# 7042    1.249327
# Name: tenure, Length: 7038, dtype: float64

# %%
# Tenure appears to not have any outliers.

# Check rows with a z-score over 3.

df[(z_scores > 3)]
# Out:
# Empty DataFrame
# Columns: [customer_id, tenure, city, zip_code, latitude, longitude, offer, phone_service, multiple_lines, internet_service, internet_type, gigabits_used, online_security, online_backup, device_protection_plan, premium_tech_support, streaming_tv, streaming_movies, unlimited_data, contract, payment_method, monthly_charge, total_charges, total_revenue, gender, age, married, kidhome, teenhome, income, churn]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# ## Step 5. Encode Categorical Values
#
# Note: After one-hot encoding, the object fields turn into integers. See the course here for more information about one-hot encoding (or encoding categorical values).

# %%
categorical_columns = df.select_dtypes(include=['object']).columns
print(categorical_columns)
# Out:
# Index(['customer_id', 'city', 'zip_code', 'offer', 'phone_service',
#        'multiple_lines', 'internet_service', 'internet_type',
#        'online_security', 'online_backup', 'device_protection_plan',
#        'premium_tech_support', 'streaming_tv', 'streaming_movies',
#        'unlimited_data', 'contract', 'payment_method', 'gender', 'married',
#        'churn'],
#       dtype='object')

# %%
#NOTE: Do not include zip code. We will need Zip Code for EDA and clustering analysis.

from sklearn.preprocessing import LabelEncoder

categorical_columns = ['customer_id', 'city', 'offer', 'phone_service',
       'multiple_lines', 'internet_service', 'internet_type',
       'online_security', 'online_backup', 'device_protection_plan',
       'premium_tech_support', 'streaming_tv', 'streaming_movies',
       'unlimited_data', 'contract', 'payment_method', 'gender', 'married',
       'churn']

#--------------------------------------------------------------------------
# EXERCISE STARTS HERE #

# Enter the code to apply label encoding

# Apply label encoding
le = LabelEncoder()
for col in categorical_columns:
    df[col] = le.fit_transform(df[col].astype(str))

# %%
# Verify data types adter encodiing
df.dtypes
# Out:
# customer_id                 int64
# tenure                      int64
# city                        int64
# zip_code                   object
# latitude                  float64
# longitude                 float64
# offer                       int64
# phone_service               int64
# multiple_lines              int64
# internet_service            int64
# internet_type               int64
# gigabits_used             float64
# online_security             int64
# online_backup               int64
# device_protection_plan      int64
# premium_tech_support        int64
# streaming_tv                int64
# streaming_movies            int64
# unlimited_data              int64
# contract                    int64
# payment_method              int64
# monthly_charge            float64
# total_charges             float64
# total_revenue             float64
# gender                      int64
# age                         int64
# married                     int64
# kidhome                     int64
# teenhome                    int64
# income                    float64
# churn                       int64
# dtype: object

# %%
df.head()
# Out:
#    customer_id  tenure  city zip_code   latitude   longitude  offer  \
# 0            0       9   346    93225  34.827662 -118.999073      0
# 1            1       9   368    91206  34.162515 -118.203869      0
# 2            2       4   222    92627  33.645672 -117.922613      5
# 3            3      13   587    94553  38.014457 -122.115432      4
# 4            4       3   139    93010  34.227846 -119.079903      0
#
#    phone_service  multiple_lines  internet_service  ...  monthly_charge  \
# 0              1               0                 1  ...            65.6
# 1              1               1                 1  ...            -4.0
# 2              1               0                 1  ...            73.9
# 3              1               0                 1  ...            98.0
# 4              1               0                 1  ...            83.9
#
#    total_charges  total_revenue  gender  age  married  kidhome  teenhome  \
# 0         593.30         974.81       0   37        1        0         0
# 1         542.40         610.28       1   46        0        0         1
# 2         280.85         415.45       1   50        0        0         1
# 3        1237.85        1599.51       1   78        1        0         0
# 4         267.40         289.54       0   75        1        1         1
#
#     income  churn
# 0  30507.0      0
# 1  59892.0      0
# 2  70545.0      1
# 3  57100.0      0
# 4  49096.0      1
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Step 6. Save the processed file

# %%
# Save the clean file. We'll use it now for Data visualizaition and analytics.

df.to_csv('cleaned_telecom.csv', index=False)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # EXERCISE #1

# %%
# Load the Dataset
# !wget https://raw.githubusercontent.com/Davron030901/Data_Science/main/data/cleaned_telecom.csv
cleaned_df=pd.read_csv('/content/cleaned_telecom.csv')

# %%
cleaned_df.head()
# Out:
#    customer_id  tenure  city  zip_code   latitude   longitude  offer  \
# 0            0       9   346     93225  34.827662 -118.999073      0
# 1            1       9   368     91206  34.162515 -118.203869      0
# 2            2       4   222     92627  33.645672 -117.922613      5
# 3            3      13   587     94553  38.014457 -122.115432      4
# 4            4       3   139     93010  34.227846 -119.079903      0
#
#    phone_service  multiple_lines  internet_service  ...  monthly_charge  \
# 0              1               0                 1  ...            65.6
# 1              1               1                 1  ...            -4.0
# 2              1               0                 1  ...            73.9
# 3              1               0                 1  ...            98.0
# 4              1               0                 1  ...            83.9
#
#    total_charges  total_revenue  gender  age  married  kidhome  teenhome  \
# 0         593.30         974.81       0   37        1        0         0
# 1         542.40         610.28       1   46        0        0         1
# 2         280.85         415.45       1   50        0        0         1
# 3        1237.85        1599.51       1   78        1        0         0
# 4         267.40         289.54       0   75        1        1         1
#
#     income  churn
# 0  30507.0      0
# 1  59892.0      0
# 2  70545.0      1
# 3  57100.0      0
# 4  49096.0      1
#
# [5 rows x 31 columns]

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7038 entries, 0 to 7037
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             7038 non-null   int64
#  1   tenure                  7038 non-null   int64
#  2   city                    7038 non-null   int64
#  3   zip_code                7038 non-null   int64
#  4   latitude                7038 non-null   float64
#  5   longitude               7038 non-null   float64
#  6   offer                   7038 non-null   int64
#  7   phone_service           7038 non-null   int64
#  8   multiple_lines          7038 non-null   int64
#  9   internet_service        7038 non-null   int64
#  10  internet_type           7038 non-null   int64
#  11  gigabits_used           7038 non-null   float64
#  12  online_security         7038 non-null   int64
#  13  online_backup           7038 non-null   int64
#  14  device_protection_plan  7038 non-null   int64
#  15  premium_tech_support    7038 non-null   int64
#  16  streaming_tv            7038 non-null   int64
#  17  streaming_movies        7038 non-null   int64
#  18  unlimited_data          7038 non-null   int64
#  19  contract                7038 non-null   int64
#  20  payment_method          7038 non-null   int64
#  21  monthly_charge          7038 non-null   float64
#  22  total_charges           7038 non-null   float64
#  23  total_revenue           7038 non-null   float64
#  24  gender                  7038 non-null   int64
#  25  age                     7038 non-null   int64
#  26  married                 7038 non-null   int64
#  27  kidhome                 7038 non-null   int64
#  28  teenhome                7038 non-null   int64
#  29  income                  7038 non-null   float64
#  30  churn                   7038 non-null   int64
# dtypes: float64(7), int64(24)
# memory usage: 1.7 MB

# %% [markdown]
# ## Bar Chart

# %% [markdown]
# Count how contracts are distributed.

# %%
# Bar Plot

plt.figure(figsize=(10, 6))
sns.countplot(x='contract', data=cleaned_df)#Seaborn count plot
plt.title('Contract Distribution')
plt.xlabel('Contract')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Count the frequency of each contract.

# %%
# Mapping numeric values to contract type labels
contract_mapping = {0: 'Month-to-Month', 1: 'One Year', 2: 'Two Year'}
df['contract'] = df['contract'].map(contract_mapping)

# Count the frequencies of each contract type
contract_counts = df['contract'].value_counts()

# Labels for the contract types
labels = contract_counts.index

# Create the bar chart
plt.figure(figsize=(10, 6))
plt.bar(labels, contract_counts, color=['#66b3ff', '#99ff99', '#ffcc99'])
plt.xlabel("Contract Type")
plt.ylabel("Count")
plt.title("Contract Type Distribution")
plt.xticks(rotation=45)  # Rotate the x-axis labels for better readability
plt.show()

# %% [markdown]
# Distribution of Payment Methods

# %%
# Let's examine the payment methods and their frequencies by improving the plot.

# Payment methods and their frequencies
payment_methods = [0, 1, 2]
frequencies = [4000, 3000, 500]
labels = ['Credit Card', 'Bank Withdrawal', 'Mailed Check']  # Labels corresponding to the numeric values

# Create the bar plot
plt.bar(payment_methods, frequencies, tick_label=labels)  # Assign labels to bars

# Add labels and title
plt.xlabel("Payment Method")
plt.ylabel("Frequency")
plt.title("Distribution of Payment Methods")

# Show the plot
plt.show()

# %% [markdown]
# ## Pie Chart

# %% [markdown]
# Contract type distribution in a Pie Chart.

# %%
# Pie Chart

plt.figure(figsize=(10, 6))
plt.pie(contract_counts, labels=contract_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Contract Type Distribution')
plt.show()

# %% [markdown]
# ## Scatter Plot

# %% [markdown]
# Tenure in Months vs. Total Revenue

# %%
# Scatter Plot

plt.figure(figsize=(10, 6))
sns.scatterplot(x='tenure', y='total_revenue', data=cleaned_df)
plt.title('Tenure in Months vs. Total Revenue')
plt.xlabel('Tenure in Months')
plt.ylabel('Total Revenue')
plt.show()

# %% [markdown]
# ## Heat Map

# %% [markdown]
# Here, we do two things in one code cell. We calculate the correlation matrix and print it so that you can see the numeric values in rows and columns. To visualize these numbers, we use Seaborn.

# %%
# Calculate the correlation matrix
correlation_matrix = cleaned_df.corr()

# Display the correlation matrix
print(correlation_matrix)

# Visualize the correlation matrix
plt.figure(figsize=(25,20))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()
# Out:
#                         customer_id    tenure      city  zip_code  latitude  \
# customer_id                1.000000  0.007751  0.006751 -0.014608 -0.015163
# tenure                     0.007751  1.000000  0.016735  0.006313  0.010797
# city                       0.006751  0.016735  1.000000 -0.008032 -0.048336
# zip_code                  -0.014608  0.006313 -0.008032  1.000000  0.894737
# latitude                  -0.015163  0.010797 -0.048336  0.894737  1.000000
# longitude                  0.012790 -0.008232 -0.000818 -0.790556 -0.885953
# offer                     -0.004169 -0.325541 -0.009326 -0.014913 -0.009609
# phone_service             -0.006493  0.007903  0.003277 -0.009003 -0.019437
# multiple_lines             0.002183  0.331226  0.009686 -0.021808 -0.029253
# internet_service           0.006088  0.038018  0.006981 -0.017034 -0.033504
# internet_type             -0.015158 -0.001666  0.009363  0.000657 -0.005090
# gigabits_used             -0.004106  0.033620  0.010865 -0.002888 -0.012351
# online_security            0.015396  0.326325  0.008739  0.008348  0.010213
# online_backup             -0.000472  0.359553  0.002650 -0.004779 -0.002746
# device_protection_plan    -0.003802  0.359928  0.006889  0.005285 -0.000771
# premium_tech_support       0.003818  0.323341 -0.014306  0.015956  0.014258
# streaming_tv              -0.004523  0.278893  0.021823  0.002348 -0.004703
# streaming_movies          -0.012670  0.284909  0.015396  0.002689 -0.005918
# unlimited_data            -0.017659 -0.003738 -0.001605  0.003828  0.003262
# contract                   0.015846  0.646041 -0.004771  0.015993  0.027672
# payment_method             0.011699 -0.052217  0.009598  0.018815  0.016837
# monthly_charge            -0.007868  0.237583  0.013440 -0.003414 -0.022894
# total_charges              0.000195  0.825896  0.018885  0.000560 -0.004791
# total_revenue             -0.000357  0.853266  0.015992  0.001367 -0.002157
# gender                     0.005987  0.005868  0.011449  0.021502  0.013636
# age                        0.006129  0.009865 -0.006955 -0.007979 -0.010140
# married                   -0.027249  0.380159  0.020338 -0.001959  0.000583
# kidhome                    0.012906  0.005255 -0.013555  0.007974  0.009985
# teenhome                   0.001582  0.018396 -0.012337  0.004892  0.014949
# income                    -0.016786 -0.005580  0.020276 -0.014405 -0.006600
# churn                      0.010637 -0.027420 -0.006478 -0.006114 -0.001553
# CLV                       -0.000222  0.856869  0.011143  0.000447 -0.001129
# total_services_used       -0.000536  0.442558  0.011417  0.001916 -0.007300
#
#                         longitude     offer  phone_service  multiple_lines  \
# customer_id              0.012790 -0.004169      -0.006493        0.002183
# tenure                  -0.008232 -0.325541       0.007903        0.331226
# city                    -0.000818 -0.009326       0.003277        0.009686
# zip_code                -0.790556 -0.014913      -0.009003       -0.021808
# latitude                -0.885953 -0.009609      -0.019437       -0.029253
# longitude                1.000000  0.015307       0.017665        0.026396
# offer                    0.015307  1.000000       0.001264       -0.093004
# phone_service            0.017665  0.001264       1.000000        0.279564
# multiple_lines           0.026396 -0.093004       0.279564        1.000000
# internet_service         0.037506 -0.009391      -0.172355        0.210249
# internet_type           -0.008837 -0.006136       0.406950        0.175918
# gigabits_used            0.013670  0.005971      -0.013894       -0.023291
# online_security         -0.011866 -0.096553      -0.093346        0.096929
# online_backup            0.012492 -0.108580      -0.052670        0.201325
# device_protection_plan   0.005782 -0.111961      -0.071599        0.200221
# premium_tech_support    -0.012895 -0.112977      -0.096791        0.099405
# streaming_tv             0.013638 -0.103180      -0.022882        0.256370
# streaming_movies         0.003944 -0.096300      -0.033271        0.257977
# unlimited_data          -0.004422  0.003553       0.043502       -0.037847
# contract                -0.023013 -0.214621       0.002359        0.119403
# payment_method          -0.016293  0.029923      -0.018504       -0.152430
# monthly_charge           0.022613 -0.072361       0.234024        0.466691
# total_charges            0.006288 -0.263823       0.112774        0.467812
# total_revenue            0.003826 -0.271714       0.174665        0.465815
# gender                  -0.013788  0.016713      -0.006348       -0.007913
# age                      0.007683 -0.029463       0.009954        0.103156
# married                  0.004198 -0.127223       0.017565        0.141651
# kidhome                 -0.009330 -0.003899       0.013230        0.025853
# teenhome                -0.013034 -0.003746      -0.004748        0.010367
# income                   0.001879 -0.003121      -0.002639       -0.030206
# churn                    0.000991  0.027234      -0.026421       -0.028010
# CLV                      0.000564 -0.263111       0.130333        0.418905
# total_services_used      0.012730 -0.143126       0.024951        0.333381
#
#                         internet_service  ...  total_revenue    gender  \
# customer_id                     0.006088  ...      -0.000357  0.005987
# tenure                          0.038018  ...       0.853266  0.005868
# city                            0.006981  ...       0.015992  0.011449
# zip_code                       -0.017034  ...       0.001367  0.021502
# latitude                       -0.033504  ...      -0.002157  0.013636
# longitude                       0.037506  ...       0.003826 -0.013788
# offer                          -0.009391  ...      -0.271714  0.016713
# phone_service                  -0.172355  ...       0.174665 -0.006348
# multiple_lines                  0.210249  ...       0.465815 -0.007913
# internet_service                1.000000  ...       0.294005 -0.005801
# internet_type                  -0.355545  ...       0.073069  0.001008
# gigabits_used                  -0.000086  ...       0.029424 -0.012576
# online_security                 0.333141  ...       0.383730 -0.016358
# online_backup                   0.381373  ...       0.473567 -0.013190
# device_protection_plan          0.380534  ...       0.474622 -0.001508
# premium_tech_support            0.336039  ...       0.394539 -0.008545
# streaming_tv                    0.415356  ...       0.460998 -0.007852
# streaming_movies                0.418481  ...       0.466372 -0.009953
# unlimited_data                 -0.184553  ...      -0.054632  0.006673
# contract                       -0.203100  ...       0.472755  0.000205
# payment_method                 -0.260089  ...      -0.118147  0.009720
# monthly_charge                  0.724656  ...       0.562009 -0.019356
# total_charges                   0.375281  ...       0.972085  0.001039
# total_revenue                   0.294005  ...       1.000000  0.004460
# gender                         -0.005801  ...       0.004460  1.000000
# age                             0.117376  ...       0.048284  0.002243
# married                        -0.000853  ...       0.329327 -0.001648
# kidhome                        -0.003594  ...       0.006320 -0.005837
# teenhome                        0.041061  ...       0.025245  0.016889
# income                         -0.001536  ...      -0.001240 -0.014783
# churn                           0.004199  ...      -0.024079 -0.010802
# CLV                             0.227736  ...       0.970572  0.006019
# total_services_used             0.682590  ...       0.680277 -0.014868
#
#                              age   married   kidhome  teenhome    income  \
# customer_id             0.006129 -0.027249  0.012906  0.001582 -0.016786
# tenure                  0.009865  0.380159  0.005255  0.018396 -0.005580
# city                   -0.006955  0.020338 -0.013555 -0.012337  0.020276
# zip_code               -0.007979 -0.001959  0.007974  0.004892 -0.014405
# latitude               -0.010140  0.000583  0.009985  0.014949 -0.006600
# longitude               0.007683  0.004198 -0.009330 -0.013034  0.001879
# offer                  -0.029463 -0.127223 -0.003899 -0.003746 -0.003121
# phone_service           0.009954  0.017565  0.013230 -0.004748 -0.002639
# multiple_lines          0.103156  0.141651  0.025853  0.010367 -0.030206
# internet_service        0.117376 -0.000853 -0.003594  0.041061 -0.001536
# internet_type           0.070513 -0.002834 -0.004532 -0.021839 -0.008743
# gigabits_used          -0.516526  0.066756  0.006401  0.003059 -0.003043
# online_security        -0.038122  0.142574  0.001420  0.034216  0.003615
# online_backup           0.035514  0.141024  0.014941  0.037721 -0.004240
# device_protection_plan  0.028457  0.153325 -0.001514  0.024300  0.016757
# premium_tech_support   -0.043886  0.119442 -0.012537  0.015919  0.015739
# streaming_tv            0.059757  0.124212  0.017662  0.010533 -0.011929
# streaming_movies        0.073468  0.116955  0.008939  0.018764 -0.002117
# unlimited_data         -0.027422  0.029355 -0.005240 -0.002124  0.002203
# contract                0.027834  0.277353  0.003226 -0.004109  0.014255
# payment_method         -0.112587 -0.034394 -0.002643 -0.011096  0.006280
# monthly_charge          0.134642  0.094127  0.009963  0.034814 -0.013887
# total_charges           0.059739  0.317509  0.004881  0.028195 -0.001759
# total_revenue           0.048284  0.329327  0.006320  0.025245 -0.001240
# gender                  0.002243 -0.001648 -0.005837  0.016889 -0.014783
# age                     1.000000 -0.003555 -0.014247 -0.012769  0.004453
# married                -0.003555  1.000000 -0.008588 -0.002107  0.000970
# kidhome                -0.014247 -0.008588  1.000000 -0.015655 -0.451796
# teenhome               -0.012769 -0.002107 -0.015655  1.000000  0.025481
# income                  0.004453  0.000970 -0.451796  0.025481  1.000000
# churn                   0.005455 -0.015100  0.010128  0.003160  0.001926
# CLV                     0.027819  0.329426  0.009089  0.022685  0.000401
# total_services_used     0.052160  0.181467  0.007967  0.039056  0.003084
#
#                            churn       CLV  total_services_used
# customer_id             0.010637 -0.000222            -0.000536
# tenure                 -0.027420  0.856869             0.442558
# city                   -0.006478  0.011143             0.011417
# zip_code               -0.006114  0.000447             0.001916
# latitude               -0.001553 -0.001129            -0.007300
# longitude               0.000991  0.000564             0.012730
# offer                   0.027234 -0.263111            -0.143126
# phone_service          -0.026421  0.130333             0.024951
# multiple_lines         -0.028010  0.418905             0.333381
# internet_service        0.004199  0.227736             0.682590
# internet_type           0.010470  0.048069            -0.211424
# gigabits_used          -0.012522  0.032389             0.043279
# online_security         0.003070  0.375122             0.554219
# online_backup          -0.011068  0.449003             0.615556
# device_protection_plan -0.003716  0.443208             0.674184
# premium_tech_support   -0.009450  0.381371             0.615341
# streaming_tv            0.001322  0.406809             0.683525
# streaming_movies        0.004872  0.411860             0.686382
# unlimited_data         -0.011022 -0.039570            -0.115335
# contract               -0.015579  0.518442             0.203298
# payment_method         -0.001737 -0.084244            -0.170577
# monthly_charge         -0.008968  0.473516             0.780839
# total_charges          -0.021118  0.947741             0.744224
# total_revenue          -0.024079  0.970572             0.680277
# gender                 -0.010802  0.006019            -0.014868
# age                     0.005455  0.027819             0.052160
# married                -0.015100  0.329426             0.181467
# kidhome                 0.010128  0.009089             0.007967
# teenhome                0.003160  0.022685             0.039056
# income                  0.001926  0.000401             0.003084
# churn                   1.000000 -0.020861            -0.006193
# CLV                    -0.020861  1.000000             0.618407
# total_services_used    -0.006193  0.618407             1.000000
#
# [33 rows x 33 columns]

# %% [markdown]
# Show the more meaningful relationships.

# %%
# Calculate the correlation matrix
corr = cleaned_df.corr()

plt.figure(figsize=(20, 15))  # Adjust the size as needed
sns.heatmap(corr[(corr >= 0.5) | (corr <= -0.7)],
            cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size": 10}, square=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Histogram

# %% [markdown]
# Histogram of Monthly Charges

# %%
# Histogram  with KDE
plt.figure(figsize=(10, 6))
sns.histplot(df['monthly_charge'], kde=True)
plt.title('Distribution of Monthly Charges')
plt.xlabel('Monthly Charges')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Histogram of Tenure

# %%
# Histogram of Tenure

sns.displot(cleaned_df['tenure'])
plt.title('Distribution of Tenure')
plt.xlabel('Tenure')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Distribution plot of revenue

# %%
# Distribution Plot

# It is used basically for univariant set of observations and visualizes it through a histogram i.e. only one observation
# and hence you choose one particular column of the dataset.
sns.displot(cleaned_df['total_revenue'])

# %% [markdown]
# Churn Distribution

# %%
# Count Plot
plt.figure(figsize=(10, 6))
sns.countplot(x='churn', data=df)
plt.title('Churn Distribution')
plt.xlabel('Churn')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Simple Feature Engineering

# %% [markdown]
# Create new features or transform existing ones to enhance the dataset’s predictive power.
#
# Customer Lifetime Value is a new feature - Total Revenue * Tenure.

# %% [markdown]
# ## Customer Lifetime Value

# %%
# Simple Feature Engineering

# Assuming CLV can be approximated as Total Revenue * Tenure for simplicity
cleaned_df['CLV'] = cleaned_df['total_revenue'] * cleaned_df['tenure']

# Drop the Total Revenue and Tenure columns as they are now part of CLV

cleaned_df.drop(columns=['total_revenue', 'tenure'], inplace=True)

# %%
# Note that 30 columns are showing now and that CLV is now a feature - at the very end.

cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7038 entries, 0 to 7037
# Data columns (total 32 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             7038 non-null   int64
#  1   tenure                  7038 non-null   int64
#  2   city                    7038 non-null   int64
#  3   zip_code                7038 non-null   int64
#  4   latitude                7038 non-null   float64
#  5   longitude               7038 non-null   float64
#  6   offer                   7038 non-null   int64
#  7   phone_service           7038 non-null   int64
#  8   multiple_lines          7038 non-null   int64
#  9   internet_service        7038 non-null   int64
#  10  internet_type           7038 non-null   int64
#  11  gigabits_used           7038 non-null   float64
#  12  online_security         7038 non-null   int64
#  13  online_backup           7038 non-null   int64
#  14  device_protection_plan  7038 non-null   int64
#  15  premium_tech_support    7038 non-null   int64
#  16  streaming_tv            7038 non-null   int64
#  17  streaming_movies        7038 non-null   int64
#  18  unlimited_data          7038 non-null   int64
#  19  contract                7038 non-null   int64
#  20  payment_method          7038 non-null   int64
#  21  monthly_charge          7038 non-null   float64
#  22  total_charges           7038 non-null   float64
#  23  total_revenue           7038 non-null   float64
#  24  gender                  7038 non-null   int64
#  25  age                     7038 non-null   int64
#  26  married                 7038 non-null   int64
#  27  kidhome                 7038 non-null   int64
#  28  teenhome                7038 non-null   int64
#  29  income                  7038 non-null   float64
#  30  churn                   7038 non-null   int64
#  31  CLV                     7038 non-null   float64
# dtypes: float64(8), int64(24)
# memory usage: 1.7 MB

# %% [markdown]
# ## Total Services Used

# %%
# Total Services Used
cleaned_df['total_services_used'] = (cleaned_df['phone_service'] + cleaned_df['internet_service'] + cleaned_df['streaming_tv'] + cleaned_df['streaming_movies'] +
                             cleaned_df['online_security'] + cleaned_df['online_backup'] + cleaned_df['device_protection_plan'] + cleaned_df['premium_tech_support'])

# %%
# Total Services Used is now a new feature at the very end of the list.

cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7038 entries, 0 to 7037
# Data columns (total 33 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             7038 non-null   int64
#  1   tenure                  7038 non-null   int64
#  2   city                    7038 non-null   int64
#  3   zip_code                7038 non-null   int64
#  4   latitude                7038 non-null   float64
#  5   longitude               7038 non-null   float64
#  6   offer                   7038 non-null   int64
#  7   phone_service           7038 non-null   int64
#  8   multiple_lines          7038 non-null   int64
#  9   internet_service        7038 non-null   int64
#  10  internet_type           7038 non-null   int64
#  11  gigabits_used           7038 non-null   float64
#  12  online_security         7038 non-null   int64
#  13  online_backup           7038 non-null   int64
#  14  device_protection_plan  7038 non-null   int64
#  15  premium_tech_support    7038 non-null   int64
#  16  streaming_tv            7038 non-null   int64
#  17  streaming_movies        7038 non-null   int64
#  18  unlimited_data          7038 non-null   int64
#  19  contract                7038 non-null   int64
#  20  payment_method          7038 non-null   int64
#  21  monthly_charge          7038 non-null   float64
#  22  total_charges           7038 non-null   float64
#  23  total_revenue           7038 non-null   float64
#  24  gender                  7038 non-null   int64
#  25  age                     7038 non-null   int64
#  26  married                 7038 non-null   int64
#  27  kidhome                 7038 non-null   int64
#  28  teenhome                7038 non-null   int64
#  29  income                  7038 non-null   float64
#  30  churn                   7038 non-null   int64
#  31  CLV                     7038 non-null   float64
#  32  total_services_used     7038 non-null   int64
# dtypes: float64(8), int64(25)
# memory usage: 1.8 MB

# %% [markdown]
# ### SAVE the cleaned file: Run the Cell to save the cleaned file.

# %%
# Save the clean file. We'll use it now for Data visualizaition and analytics.

df.to_csv('eda_telecom.csv', index=False)
